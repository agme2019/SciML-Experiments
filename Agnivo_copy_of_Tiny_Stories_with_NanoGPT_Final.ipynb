# %% [markdown]
# <a href="https://colab.research.google.com/github/agme2019/SciML-Experiments/blob/main/Agnivo_copy_of_Tiny_Stories_with_NanoGPT_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction
#
# In this notebook, we’ll explore how to train a lightweight NanoGPT on the Tiny Stories dataset. NanoGPT, developed by Andrej Karpathy, is a simplified variant of GPT designed for simplicity and speed. Our goal is to generate creative and coherent text based on the input data. I will also use Wandb library to track the experiments on the model.

# %% [markdown]
# # Import Libraries

# %%
# Clone the NanoGPT
# !git clone https://github.com/karpathy/nanoGPT.git
# !pip install tiktoken
# Out:
# Cloning into 'nanoGPT'...
# remote: Enumerating objects: 682, done.
# remote: Total 682 (delta 0), reused 0 (delta 0), pack-reused 682 (from 1)
# Receiving objects: 100% (682/682), 952.47 KiB | 2.94 MiB/s, done.
# Resolving deltas: 100% (385/385), done.
# Collecting tiktoken
#   Downloading tiktoken-0.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2024.9.11)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (2024.8.30)
# Downloading tiktoken-0.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 12.2 MB/s eta 0:00:00
# Installing collected packages: tiktoken
# Successfully installed tiktoken-0.8.0

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
from tqdm.auto import tqdm
from contextlib import nullcontext
import nanoGPT.model as GPT
import wandb
import os

# %%
# from kaggle_secrets import UserSecretsClient
# # Load API keys https://www.kaggle.com/discussions/product-feedback/114053
# secret_label = "WANDB_API_KEY"
my_secret = "c2e3619f245387906ce0bd58733dc79534a116bc"

# %%
class GPTConfig: # Model config from NanoGPT
    block_size: int = 256 # increased from 256
    vocab_size: int = 50304 # GPT-2 vocab_size of 50257, padded up to nearest multiple of 64 for efficiency
    n_layer: int = 12
    n_head: int = 8 # same
    n_embd: int = 192 # changed from 384
    dropout: float = 0.2
    bias: bool = True # True: bias in Linears and LayerNorms, like GPT-2. False: a bit better and faster

config = GPTConfig

# %%
wandb_config = {k:v for k,v in vars(config).items() if not callable(getattr(config, k)) and not k.startswith("__")} # Creating Wandb hyperparameters config for tracking experiements
wandb_config
# Out:
# {'block_size': 256,
#  'vocab_size': 50304,
#  'n_layer': 12,
#  'n_head': 8,
#  'n_embd': 192,
#  'dropout': 0.2,
#  'bias': True}

# %%
wandb.login(key=my_secret)
# Out:
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %% [markdown]
# # Tiny Stories datasets and preprocessing
#
# TinyStories, a synthetic dataset of short stories that only contain words that a typical 3 to 4-year-olds usually understand, generated by GPT-3.5 and GPT-4. We show that TinyStories can be used to train and evaluate LMs that are much smaller than the state-of-the-art models (below 10 million total parameters)

# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-3.0.2-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (16.1.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.5)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.10.10)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.24.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.16.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets) (0.2.0)
# Downloading datasets-3.0.2-py3-none-any.whl (472 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.7/472.7 kB 8.9 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.8 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 14.7 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 18.0 MB/s eta 0:00:00
# Installing collected packages: xxhash, dill, multiprocess, datasets
# Successfully installed datasets-3.0.2 dill-0.3.8 multiprocess-0.70.16 xxhash-3.5.0

# %%
from datasets import load_dataset

ds = load_dataset("roneneldan/TinyStories")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/1.06k [00:00<?, ?B/s]
# (…)-00000-of-00004-2d5a1467fff1081b.parquet:   0%|          | 0.00/249M [00:00<?, ?B/s]
# (…)-00001-of-00004-5852b56a2bd28fd9.parquet:   0%|          | 0.00/248M [00:00<?, ?B/s]
# (…)-00002-of-00004-a26307300439e943.parquet:   0%|          | 0.00/246M [00:00<?, ?B/s]
# (…)-00003-of-00004-d243063613e5a057.parquet:   0%|          | 0.00/248M [00:00<?, ?B/s]
# (…)-00000-of-00001-869c898b519ad725.parquet:   0%|          | 0.00/9.99M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/2119719 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/21990 [00:00<?, ? examples/s]

# %%
import tiktoken
import os

enc = tiktoken.get_encoding("gpt2")

# Some functions from https://github.com/karpathy/nanoGPT/blob/master/data/openwebtext/prepare.py

def process(example):
    ids = enc.encode_ordinary(example['text']) # encode_ordinary ignores any special tokens
    out = {'ids': ids, 'len': len(ids)}
    return out

if not os.path.exists("train.bin"):
    tokenized = ds.map(
        process,
        remove_columns=['text'],
        desc="tokenizing the splits",
        num_proc=8,
        )
    # concatenate all the ids in each dataset into one large file we can use for training
    for split, dset in tokenized.items():
        arr_len = np.sum(dset['len'], dtype=np.uint64)
        filename = f'{split}.bin'
        dtype = np.uint16 # (can do since enc.max_token_value == 50256 is < 2**16)
        arr = np.memmap(filename, dtype=dtype, mode='w+', shape=(arr_len,))
        total_batches = 1024

        idx = 0
        for batch_idx in tqdm(range(total_batches), desc=f'writing {filename}'):
            # Batch together samples for faster write
            batch = dset.shard(num_shards=total_batches, index=batch_idx, contiguous=True).with_format('numpy')
            arr_batch = np.concatenate(batch['ids'])
            # Write into mmap
            arr[idx : idx + len(arr_batch)] = arr_batch
            idx += len(arr_batch)
        arr.flush()
# Out:
# tokenizing the splits (num_proc=8):   0%|          | 0/2119719 [00:00<?, ? examples/s]
# tokenizing the splits (num_proc=8):   0%|          | 0/21990 [00:00<?, ? examples/s]
# writing train.bin:   0%|          | 0/1024 [00:00<?, ?it/s]
# writing validation.bin:   0%|          | 0/1024 [00:00<?, ?it/s]

# %% [markdown]
# # Training

# %%
# Some functions from https://github.com/karpathy/nanoGPT/blob/master/train.py with slight modifications
def get_batch(split):
    # We recreate np.memmap every batch to avoid a memory leak, as per
    # https://stackoverflow.com/questions/45132940/numpy-memmap-memory-usage-want-to-iterate-once/61472122#61472122
    if split == 'train':
        data = np.memmap('train.bin', dtype=np.uint16, mode='r')
    else:
        data = np.memmap('validation.bin', dtype=np.uint16, mode='r')
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([torch.from_numpy((data[i:i+block_size]).astype(np.int64)) for i in ix])
    y = torch.stack([torch.from_numpy((data[i+1:i+1+block_size]).astype(np.int64)) for i in ix])
    if device_type == 'cuda':
        # pin arrays x,y, which allows us to move them to GPU asynchronously (non_blocking=True)
        x, y = x.pin_memory().to(device, non_blocking=True), y.pin_memory().to(device, non_blocking=True)
    else:
        x, y = x.to(device), y.to(device)
    return x, y


def estimate_loss(model):
    out = {}
    model.eval()
    with torch.inference_mode():
        for split in ['train', 'val']:
            losses = torch.zeros(eval_iters)
            for k in range(eval_iters):
                X, Y = get_batch(split)
                with ctx:
                    logits, loss = model(X, Y)
                losses[k] = loss.item()
            out[split] = losses.mean()
    model.train()
    return out

# %%
# Training Config

learning_rate = 1e-4 #more stable training, earlier 1e-4
max_iters = 600000 #increase from 25000
warmup_steps = 1000 #smoother initial train, earlier 100
min_lr = 5e-4 #lower rate, earlier 5e-4
eval_iters = 500 # increased from 100
batch_size = 32 # changed from 16, better gradient estimate
block_size = 128 #changed from 64, capture longer range dependencies

gradient_accumulation_steps = 32 # reduced from 50

device =  "cuda" if torch.cuda.is_available() else "cpu"
device_type = 'cuda' if 'cuda' in device else 'cpu' # for later use in torch.autocast
# note: float16 data type will automatically use a GradScaler

# How to use autocast https://wandb.ai/wandb_fc/tips/reports/How-To-Use-Autocast-in-PyTorch--VmlldzoyMTk4NTky
dtype = 'bfloat16' if torch.cuda.is_available() and torch.cuda.is_bf16_supported() else 'float16' # 'float32', 'bfloat16', or 'float16', the latter will auto implement a GradScaler
ptdtype = {'float32': torch.float32, 'bfloat16': torch.bfloat16, 'float16': torch.float16}[dtype]

ctx = nullcontext() if device_type == 'cpu' else torch.amp.autocast(device_type=device_type, dtype=ptdtype)

torch.set_default_device(device)
torch.manual_seed(42)

# %%
from torch.optim.lr_scheduler import LinearLR,SequentialLR, CosineAnnealingLR

nanoGPT = GPT.GPT(config)
##PUT IN WEIGHT DECAY, CHANGED BETA2 to 0.95
optimizer =  torch.optim.AdamW(nanoGPT.parameters(), lr=learning_rate, betas=(0.9, 0.95), weight_decay=0.1, eps=1e-9) #weight decay for regularization

scheduler_warmup = LinearLR(optimizer, total_iters = warmup_steps) #Implement linear warmup
scheduler_decay = CosineAnnealingLR(optimizer,T_max = max_iters - warmup_steps, eta_min = min_lr) #Implement lr decay
scheduler = SequentialLR(optimizer, schedulers=[scheduler_warmup, scheduler_decay], milestones=[warmup_steps]) #Switching from warmup to decay

# https://stackoverflow.com/questions/72534859/is-gradscaler-necessary-with-mixed-precision-training-with-pytorch
scaler = torch.cuda.amp.GradScaler(enabled=(dtype == 'float16'))
# Out:
# number of parameters: 15.00M
# <ipython-input-12-796f8fa3ac05>:12: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=(dtype == 'float16'))

# %%
wandb.init(project="nanogpt-tinystories", name="nanoGPT-sml-longer", config=wandb_config)

best_val_loss = float('inf')
best_model_params_path = "best_model_params.pt"
train_loss_list, validation_loss_list = [], []

for epoch in tqdm(range(max_iters)):
    if epoch%eval_iters == 0 and epoch != 0:
        losses = estimate_loss(nanoGPT)
        print(f"Epoch {epoch}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")
        print(f"The current learning rate: {optimizer.param_groups[0]['lr']:.5f}")
        train_loss_list += [losses['train']]
        validation_loss_list += [losses['val']]

        wandb.log({
                "epoch": epoch,
                "train/loss": losses['train'],
                "val/loss": losses['val'],
                "lr": optimizer.param_groups[0]['lr']
            })

        if losses['val'] < best_val_loss:
            best_val_loss = losses['val']
            torch.save(nanoGPT.state_dict(), best_model_params_path)

    X,y = get_batch("train")

    with ctx:
        logits, loss = nanoGPT(X, y)
        loss = loss / gradient_accumulation_steps # scale the loss to account for gradient accumulation
        scaler.scale(loss).backward()

    if ((epoch + 1) % gradient_accumulation_steps == 0) or (epoch + 1 == max_iters):
        torch.nn.utils.clip_grad_norm_(nanoGPT.parameters(), max_norm=0.5)
        scaler.step(optimizer)
        scaler.update()
        optimizer.zero_grad(set_to_none=True)
    scheduler.step()


wandb.finish()
# Out:
# wandb: Currently logged in as: nisargbhavsar. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.18.5
# Run data is saved locally in <code>/content/wandb/run-20241027_195305-ac0fpxn5</code>
# Syncing run <strong><a href='https://wandb.ai/nisargbhavsar/nanogpt-tinystories/runs/ac0fpxn5' target="_blank">nanoGPT-sml-longer</a></strong> to <a href='https://wandb.ai/nisargbhavsar/nanogpt-tinystories' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/nisargbhavsar/nanogpt-tinystories' target="_blank">https://wandb.ai/nisargbhavsar/nanogpt-tinystories</a>
#  View run at <a href='https://wandb.ai/nisargbhavsar/nanogpt-tinystories/runs/ac0fpxn5' target="_blank">https://wandb.ai/nisargbhavsar/nanogpt-tinystories/runs/ac0fpxn5</a>
#   0%|          | 0/600000 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:224: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn(
# Epoch 500: train loss 10.0973, val loss 10.1035
# The current learning rate: 0.00007
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:240: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
# Epoch 1000: train loss 9.6385, val loss 9.6430
# The current learning rate: 0.00010
# Epoch 1500: train loss 9.1469, val loss 9.1484
# The current learning rate: 0.00010
# Epoch 2000: train loss 8.6391, val loss 8.6409
# The current learning rate: 0.00010
# Epoch 2500: train loss 8.1683, val loss 8.1711
# The current learning rate: 0.00010
# Epoch 3000: train loss 7.7617, val loss 7.7663
# The current learning rate: 0.00010
# Epoch 3500: train loss 7.3623, val loss 7.3649
# The current learning rate: 0.00010
# Epoch 4000: train loss 7.0005, val loss 7.0000
# The current learning rate: 0.00010
# Epoch 4500: train loss 6.6930, val loss 6.6931
# The current learning rate: 0.00010
# Epoch 5000: train loss 6.3983, val loss 6.3975
# The current learning rate: 0.00010
# Epoch 5500: train loss 6.1532, val loss 6.1528
# The current learning rate: 0.00010
# Epoch 6000: train loss 5.9174, val loss 5.9209
# The current learning rate: 0.00010
# Epoch 6500: train loss 5.7013, val loss 5.7066
# The current learning rate: 0.00010
# Epoch 7000: train loss 5.5243, val loss 5.5203
# The current learning rate: 0.00010
# Epoch 7500: train loss 5.3513, val loss 5.3546
# The current learning rate: 0.00010
# Epoch 8000: train loss 5.1890, val loss 5.1899
# The current learning rate: 0.00010
# Epoch 8500: train loss 5.0523, val loss 5.0469
# The current learning rate: 0.00010
# Epoch 9000: train loss 4.9151, val loss 4.9151
# The current learning rate: 0.00010
# Epoch 9500: train loss 4.7978, val loss 4.7981
# The current learning rate: 0.00010
# Epoch 10000: train loss 4.6886, val loss 4.6894
# The current learning rate: 0.00010
# Epoch 10500: train loss 4.5822, val loss 4.5855
# The current learning rate: 0.00010
# Epoch 11000: train loss 4.4921, val loss 4.4918
# The current learning rate: 0.00010
# Epoch 11500: train loss 4.4092, val loss 4.4101
# The current learning rate: 0.00010
# Epoch 12000: train loss 4.3195, val loss 4.3205
# The current learning rate: 0.00010
# Epoch 12500: train loss 4.2639, val loss 4.2637
# The current learning rate: 0.00010
# Epoch 13000: train loss 4.1968, val loss 4.2041
# The current learning rate: 0.00010
# Epoch 13500: train loss 4.1305, val loss 4.1399
# The current learning rate: 0.00010
# Epoch 14000: train loss 4.0714, val loss 4.0715
# The current learning rate: 0.00010
# Epoch 14500: train loss 4.0165, val loss 4.0180
# The current learning rate: 0.00010
# Epoch 15000: train loss 3.9678, val loss 3.9646
# The current learning rate: 0.00010
# Epoch 15500: train loss 3.9128, val loss 3.9112
# The current learning rate: 0.00010
# Epoch 16000: train loss 3.8648, val loss 3.8662
# The current learning rate: 0.00010
# Epoch 16500: train loss 3.8234, val loss 3.8269
# The current learning rate: 0.00010
# Epoch 17000: train loss 3.7847, val loss 3.7858
# The current learning rate: 0.00010
# Epoch 17500: train loss 3.7449, val loss 3.7503
# The current learning rate: 0.00010
# Epoch 18000: train loss 3.7096, val loss 3.7119
# The current learning rate: 0.00010
# Epoch 18500: train loss 3.6822, val loss 3.6768
# The current learning rate: 0.00010
# Epoch 19000: train loss 3.6463, val loss 3.6555
# The current learning rate: 0.00010
# Epoch 19500: train loss 3.6145, val loss 3.6220
# The current learning rate: 0.00010
# Epoch 20000: train loss 3.5851, val loss 3.5906
# The current learning rate: 0.00010
# Epoch 20500: train loss 3.5538, val loss 3.5637
# The current learning rate: 0.00010
# Epoch 21000: train loss 3.5342, val loss 3.5368
# The current learning rate: 0.00010
# Epoch 21500: train loss 3.5006, val loss 3.5122
# The current learning rate: 0.00010
# Epoch 22000: train loss 3.4812, val loss 3.4823
# The current learning rate: 0.00010
# Epoch 22500: train loss 3.4529, val loss 3.4629
# The current learning rate: 0.00010
# Epoch 23000: train loss 3.4376, val loss 3.4389
# The current learning rate: 0.00010
# Epoch 23500: train loss 3.4124, val loss 3.4223
# The current learning rate: 0.00010
# Epoch 24000: train loss 3.3927, val loss 3.3969
# The current learning rate: 0.00010
# Epoch 24500: train loss 3.3712, val loss 3.3778
# The current learning rate: 0.00010
# Epoch 25000: train loss 3.3432, val loss 3.3512
# The current learning rate: 0.00010
# Epoch 25500: train loss 3.3249, val loss 3.3242
# The current learning rate: 0.00010
# Epoch 26000: train loss 3.3055, val loss 3.3167
# The current learning rate: 0.00010
# Epoch 26500: train loss 3.2919, val loss 3.2963
# The current learning rate: 0.00010
# Epoch 27000: train loss 3.2883, val loss 3.2863
# The current learning rate: 0.00010
# Epoch 27500: train loss 3.2650, val loss 3.2642
# The current learning rate: 0.00010
# Epoch 28000: train loss 3.2433, val loss 3.2418
# The current learning rate: 0.00010
# Epoch 28500: train loss 3.2336, val loss 3.2290
# The current learning rate: 0.00010
# Epoch 29000: train loss 3.2120, val loss 3.2147
# The current learning rate: 0.00010
# Epoch 29500: train loss 3.2013, val loss 3.1947
# The current learning rate: 0.00010
# Epoch 30000: train loss 3.1921, val loss 3.1936
# The current learning rate: 0.00010
# Epoch 30500: train loss 3.1698, val loss 3.1747
# The current learning rate: 0.00010
# Epoch 31000: train loss 3.1495, val loss 3.1616
# The current learning rate: 0.00010
# Epoch 31500: train loss 3.1396, val loss 3.1449
# The current learning rate: 0.00010
# Epoch 32000: train loss 3.1365, val loss 3.1310
# The current learning rate: 0.00010
# Epoch 32500: train loss 3.1117, val loss 3.1218
# The current learning rate: 0.00010
# Epoch 33000: train loss 3.1008, val loss 3.1032
# The current learning rate: 0.00010
# Epoch 33500: train loss 3.0874, val loss 3.0910
# The current learning rate: 0.00010
# Epoch 34000: train loss 3.0755, val loss 3.0740
# The current learning rate: 0.00010
# Epoch 34500: train loss 3.0684, val loss 3.0677
# The current learning rate: 0.00010
# Epoch 35000: train loss 3.0459, val loss 3.0601
# The current learning rate: 0.00010
# Epoch 35500: train loss 3.0318, val loss 3.0380
# The current learning rate: 0.00010
# Epoch 36000: train loss 3.0343, val loss 3.0295
# The current learning rate: 0.00010
# Epoch 36500: train loss 3.0132, val loss 3.0272
# The current learning rate: 0.00010
# Epoch 37000: train loss 3.0046, val loss 3.0112
# The current learning rate: 0.00010
# Epoch 37500: train loss 2.9933, val loss 2.9920
# The current learning rate: 0.00010
# Epoch 38000: train loss 2.9820, val loss 2.9868
# The current learning rate: 0.00010
# Epoch 38500: train loss 2.9666, val loss 2.9651
# The current learning rate: 0.00010
# Epoch 39000: train loss 2.9637, val loss 2.9635
# The current learning rate: 0.00010
# Epoch 39500: train loss 2.9534, val loss 2.9532
# The current learning rate: 0.00010
# Epoch 40000: train loss 2.9462, val loss 2.9453
# The current learning rate: 0.00010
# Epoch 40500: train loss 2.9389, val loss 2.9409
# The current learning rate: 0.00010
# Epoch 41000: train loss 2.9166, val loss 2.9292
# The current learning rate: 0.00010
# Epoch 41500: train loss 2.9189, val loss 2.9190
# The current learning rate: 0.00010
# Epoch 42000: train loss 2.8995, val loss 2.9060
# The current learning rate: 0.00010
# Epoch 42500: train loss 2.9025, val loss 2.9029
# The current learning rate: 0.00010
# Epoch 43000: train loss 2.8871, val loss 2.8893
# The current learning rate: 0.00010
# Epoch 43500: train loss 2.8775, val loss 2.8871
# The current learning rate: 0.00010
# Epoch 44000: train loss 2.8692, val loss 2.8689
# The current learning rate: 0.00011
# Epoch 44500: train loss 2.8634, val loss 2.8706
# The current learning rate: 0.00011
# Epoch 45000: train loss 2.8519, val loss 2.8524
# The current learning rate: 0.00011
# Epoch 45500: train loss 2.8468, val loss 2.8477
# The current learning rate: 0.00011
# Epoch 46000: train loss 2.8362, val loss 2.8389
# The current learning rate: 0.00011
# Epoch 46500: train loss 2.8272, val loss 2.8258
# The current learning rate: 0.00011
# Epoch 47000: train loss 2.8237, val loss 2.8226
# The current learning rate: 0.00011
# Epoch 47500: train loss 2.8124, val loss 2.8129
# The current learning rate: 0.00011
# Epoch 48000: train loss 2.8032, val loss 2.8037
# The current learning rate: 0.00011
# Epoch 48500: train loss 2.7956, val loss 2.7968
# The current learning rate: 0.00011
# Epoch 49000: train loss 2.7904, val loss 2.7889
# The current learning rate: 0.00011
# Epoch 49500: train loss 2.7743, val loss 2.7862
# The current learning rate: 0.00011
# Epoch 50000: train loss 2.7716, val loss 2.7817
# The current learning rate: 0.00011
# Epoch 50500: train loss 2.7646, val loss 2.7677
# The current learning rate: 0.00011
# Epoch 51000: train loss 2.7632, val loss 2.7694
# The current learning rate: 0.00011
# Epoch 51500: train loss 2.7572, val loss 2.7587
# The current learning rate: 0.00011
# Epoch 52000: train loss 2.7438, val loss 2.7501
# The current learning rate: 0.00011
# Epoch 52500: train loss 2.7393, val loss 2.7416
# The current learning rate: 0.00011
# Epoch 53000: train loss 2.7352, val loss 2.7358
# The current learning rate: 0.00011
# Epoch 53500: train loss 2.7327, val loss 2.7350
# The current learning rate: 0.00011
# Epoch 54000: train loss 2.7186, val loss 2.7180
# The current learning rate: 0.00011
# Epoch 54500: train loss 2.7178, val loss 2.7137
# The current learning rate: 0.00011
# Epoch 55000: train loss 2.6988, val loss 2.7134
# The current learning rate: 0.00011
# Epoch 55500: train loss 2.6969, val loss 2.6968
# The current learning rate: 0.00011
# Epoch 56000: train loss 2.6951, val loss 2.7012
# The current learning rate: 0.00011
# Epoch 56500: train loss 2.6909, val loss 2.6988
# The current learning rate: 0.00011
# Epoch 57000: train loss 2.6829, val loss 2.6815
# The current learning rate: 0.00011
# Epoch 57500: train loss 2.6745, val loss 2.6821
# The current learning rate: 0.00011
# Epoch 58000: train loss 2.6687, val loss 2.6726
# The current learning rate: 0.00011
# Epoch 58500: train loss 2.6641, val loss 2.6639
# The current learning rate: 0.00011
# Epoch 59000: train loss 2.6651, val loss 2.6572
# The current learning rate: 0.00011
# Epoch 59500: train loss 2.6489, val loss 2.6603
# The current learning rate: 0.00011
# Epoch 60000: train loss 2.6356, val loss 2.6393
# The current learning rate: 0.00011
# Epoch 60500: train loss 2.6400, val loss 2.6477
# The current learning rate: 0.00011
# Epoch 61000: train loss 2.6387, val loss 2.6425
# The current learning rate: 0.00011
# Epoch 61500: train loss 2.6284, val loss 2.6400
# The current learning rate: 0.00011
# Epoch 62000: train loss 2.6177, val loss 2.6260
# The current learning rate: 0.00011
# Epoch 62500: train loss 2.6184, val loss 2.6211
# The current learning rate: 0.00011
# Epoch 63000: train loss 2.6112, val loss 2.6234
# The current learning rate: 0.00011
# Epoch 63500: train loss 2.6051, val loss 2.6122
# The current learning rate: 0.00011
# Epoch 64000: train loss 2.5962, val loss 2.6070
# The current learning rate: 0.00011
# Epoch 64500: train loss 2.5938, val loss 2.5992
# The current learning rate: 0.00011
# Epoch 65000: train loss 2.5946, val loss 2.5973
# The current learning rate: 0.00011
# Epoch 65500: train loss 2.5888, val loss 2.5891
# The current learning rate: 0.00011
# Epoch 66000: train loss 2.5759, val loss 2.5891
# The current learning rate: 0.00011
# Epoch 66500: train loss 2.5760, val loss 2.5807
# The current learning rate: 0.00011
# Epoch 67000: train loss 2.5704, val loss 2.5755
# The current learning rate: 0.00011
# Epoch 67500: train loss 2.5681, val loss 2.5620
# The current learning rate: 0.00011
# Epoch 68000: train loss 2.5620, val loss 2.5628
# The current learning rate: 0.00011
# Epoch 68500: train loss 2.5532, val loss 2.5657
# The current learning rate: 0.00011
# Epoch 69000: train loss 2.5577, val loss 2.5576
# The current learning rate: 0.00011
# Epoch 69500: train loss 2.5461, val loss 2.5473
# The current learning rate: 0.00011
# Epoch 70000: train loss 2.5405, val loss 2.5489
# The current learning rate: 0.00011
# Epoch 70500: train loss 2.5429, val loss 2.5388
# The current learning rate: 0.00011
# Epoch 71000: train loss 2.5299, val loss 2.5404
# The current learning rate: 0.00011
# Epoch 71500: train loss 2.5253, val loss 2.5316
# The current learning rate: 0.00011
# Epoch 72000: train loss 2.5208, val loss 2.5302
# The current learning rate: 0.00011
# Epoch 72500: train loss 2.5224, val loss 2.5237
# The current learning rate: 0.00011
# Epoch 73000: train loss 2.5172, val loss 2.5196
# The current learning rate: 0.00011
# Epoch 73500: train loss 2.5145, val loss 2.5128
# The current learning rate: 0.00011
# Epoch 74000: train loss 2.5094, val loss 2.5159
# The current learning rate: 0.00011
# Epoch 74500: train loss 2.5091, val loss 2.5108
# The current learning rate: 0.00011
# Epoch 75000: train loss 2.4971, val loss 2.5051
# The current learning rate: 0.00011
# Epoch 75500: train loss 2.4926, val loss 2.4962
# The current learning rate: 0.00012
# Epoch 76000: train loss 2.4867, val loss 2.5046
# The current learning rate: 0.00012
# Epoch 76500: train loss 2.4895, val loss 2.4902
# The current learning rate: 0.00012
# Epoch 77000: train loss 2.4747, val loss 2.4842
# The current learning rate: 0.00012
# Epoch 77500: train loss 2.4789, val loss 2.4807
# The current learning rate: 0.00012
# Epoch 78000: train loss 2.4710, val loss 2.4787
# The current learning rate: 0.00012
# Epoch 78500: train loss 2.4796, val loss 2.4804
# The current learning rate: 0.00012
# Epoch 79000: train loss 2.4620, val loss 2.4674
# The current learning rate: 0.00012
# Epoch 79500: train loss 2.4597, val loss 2.4626
# The current learning rate: 0.00012
# Epoch 80000: train loss 2.4629, val loss 2.4610
# The current learning rate: 0.00012
# Epoch 80500: train loss 2.4406, val loss 2.4611
# The current learning rate: 0.00012
# Epoch 81000: train loss 2.4473, val loss 2.4553
# The current learning rate: 0.00012
# Epoch 81500: train loss 2.4440, val loss 2.4518
# The current learning rate: 0.00012
# Epoch 82000: train loss 2.4469, val loss 2.4530
# The current learning rate: 0.00012
# Epoch 82500: train loss 2.4401, val loss 2.4450
# The current learning rate: 0.00012
# Epoch 83000: train loss 2.4422, val loss 2.4370
# The current learning rate: 0.00012
# Epoch 83500: train loss 2.4364, val loss 2.4352
# The current learning rate: 0.00012
# Epoch 84000: train loss 2.4208, val loss 2.4263
# The current learning rate: 0.00012
# Epoch 84500: train loss 2.4274, val loss 2.4338
# The current learning rate: 0.00012
# Epoch 85000: train loss 2.4250, val loss 2.4311
# The current learning rate: 0.00012
# Epoch 85500: train loss 2.4176, val loss 2.4265
# The current learning rate: 0.00012
# Epoch 86000: train loss 2.4144, val loss 2.4135
# The current learning rate: 0.00012
# Epoch 86500: train loss 2.4157, val loss 2.4142
# The current learning rate: 0.00012
# Epoch 87000: train loss 2.4082, val loss 2.4059
# The current learning rate: 0.00012
# Epoch 87500: train loss 2.4067, val loss 2.4090
# The current learning rate: 0.00012
# Epoch 88000: train loss 2.4031, val loss 2.4090
# The current learning rate: 0.00012
# Epoch 88500: train loss 2.3930, val loss 2.4035
# The current learning rate: 0.00012
# Epoch 89000: train loss 2.3943, val loss 2.3989
# The current learning rate: 0.00012
# Epoch 89500: train loss 2.3883, val loss 2.3946
# The current learning rate: 0.00012
# Epoch 90000: train loss 2.3892, val loss 2.3924
# The current learning rate: 0.00012
# Epoch 90500: train loss 2.3812, val loss 2.3847
# The current learning rate: 0.00012
# Epoch 91000: train loss 2.3830, val loss 2.3843
# The current learning rate: 0.00012
# Epoch 91500: train loss 2.3807, val loss 2.3827
# The current learning rate: 0.00012
# Epoch 92000: train loss 2.3761, val loss 2.3811
# The current learning rate: 0.00012
# Epoch 92500: train loss 2.3750, val loss 2.3800
# The current learning rate: 0.00012
# Epoch 93000: train loss 2.3689, val loss 2.3717
# The current learning rate: 0.00012
# Epoch 93500: train loss 2.3676, val loss 2.3654
# The current learning rate: 0.00012
# Epoch 94000: train loss 2.3693, val loss 2.3659
# The current learning rate: 0.00012
# Epoch 94500: train loss 2.3576, val loss 2.3704
# The current learning rate: 0.00012
# Epoch 95000: train loss 2.3509, val loss 2.3572
# The current learning rate: 0.00012
# Epoch 95500: train loss 2.3476, val loss 2.3559
# The current learning rate: 0.00012
# Epoch 96000: train loss 2.3477, val loss 2.3540
# The current learning rate: 0.00012
# Epoch 96500: train loss 2.3553, val loss 2.3563
# The current learning rate: 0.00012
# Epoch 97000: train loss 2.3451, val loss 2.3440
# The current learning rate: 0.00012
# Epoch 97500: train loss 2.3460, val loss 2.3457
# The current learning rate: 0.00013
# Epoch 98000: train loss 2.3404, val loss 2.3381
# The current learning rate: 0.00013
# Epoch 98500: train loss 2.3313, val loss 2.3426
# The current learning rate: 0.00013
# Epoch 99000: train loss 2.3288, val loss 2.3360
# The current learning rate: 0.00013
# Epoch 99500: train loss 2.3368, val loss 2.3403
# The current learning rate: 0.00013
# Epoch 100000: train loss 2.3240, val loss 2.3348
# The current learning rate: 0.00013
# Epoch 100500: train loss 2.3174, val loss 2.3295
# The current learning rate: 0.00013
# Epoch 101000: train loss 2.3175, val loss 2.3293
# The current learning rate: 0.00013
# Epoch 101500: train loss 2.3225, val loss 2.3289
# The current learning rate: 0.00013
# Epoch 102000: train loss 2.3104, val loss 2.3211
# The current learning rate: 0.00013
# Epoch 102500: train loss 2.3108, val loss 2.3236
# The current learning rate: 0.00013
# Epoch 103000: train loss 2.3070, val loss 2.3180
# The current learning rate: 0.00013
# Epoch 103500: train loss 2.3104, val loss 2.3128
# The current learning rate: 0.00013
# Epoch 104000: train loss 2.3107, val loss 2.3105
# The current learning rate: 0.00013
# Epoch 104500: train loss 2.3073, val loss 2.3016
# The current learning rate: 0.00013
# Epoch 105000: train loss 2.3018, val loss 2.3071
# The current learning rate: 0.00013
# Epoch 105500: train loss 2.3001, val loss 2.2979
# The current learning rate: 0.00013
# Epoch 106000: train loss 2.2982, val loss 2.2982
# The current learning rate: 0.00013
# Epoch 106500: train loss 2.2936, val loss 2.2951
# The current learning rate: 0.00013
# Epoch 107000: train loss 2.2912, val loss 2.2915
# The current learning rate: 0.00013
# Epoch 107500: train loss 2.2867, val loss 2.2945
# The current learning rate: 0.00013
# Epoch 108000: train loss 2.2945, val loss 2.2887
# The current learning rate: 0.00013
# Epoch 108500: train loss 2.2841, val loss 2.2874
# The current learning rate: 0.00013
# Epoch 109000: train loss 2.2852, val loss 2.2916
# The current learning rate: 0.00013
# Epoch 109500: train loss 2.2770, val loss 2.2860
# The current learning rate: 0.00013
# Epoch 110000: train loss 2.2810, val loss 2.2755
# The current learning rate: 0.00013
# Epoch 110500: train loss 2.2717, val loss 2.2759
# The current learning rate: 0.00013
# Epoch 111000: train loss 2.2726, val loss 2.2822
# The current learning rate: 0.00013
# Epoch 111500: train loss 2.2741, val loss 2.2718
# The current learning rate: 0.00013
# Epoch 112000: train loss 2.2717, val loss 2.2694
# The current learning rate: 0.00013
# Epoch 112500: train loss 2.2627, val loss 2.2745
# The current learning rate: 0.00013
# Epoch 113000: train loss 2.2682, val loss 2.2645
# The current learning rate: 0.00013
# Epoch 113500: train loss 2.2589, val loss 2.2623
# The current learning rate: 0.00013
# Epoch 114000: train loss 2.2561, val loss 2.2648
# The current learning rate: 0.00013
# Epoch 114500: train loss 2.2527, val loss 2.2533
# The current learning rate: 0.00013
# Epoch 115000: train loss 2.2547, val loss 2.2614
# The current learning rate: 0.00013
# Epoch 115500: train loss 2.2518, val loss 2.2478
# The current learning rate: 0.00013
# Epoch 116000: train loss 2.2474, val loss 2.2481
# The current learning rate: 0.00014
# Epoch 116500: train loss 2.2427, val loss 2.2458
# The current learning rate: 0.00014
# Epoch 117000: train loss 2.2434, val loss 2.2513
# The current learning rate: 0.00014
# Epoch 117500: train loss 2.2388, val loss 2.2449
# The current learning rate: 0.00014
# Epoch 118000: train loss 2.2391, val loss 2.2390
# The current learning rate: 0.00014
# Epoch 118500: train loss 2.2419, val loss 2.2457
# The current learning rate: 0.00014
# Epoch 119000: train loss 2.2380, val loss 2.2384
# The current learning rate: 0.00014
# Epoch 119500: train loss 2.2271, val loss 2.2339
# The current learning rate: 0.00014
# Epoch 120000: train loss 2.2281, val loss 2.2368
# The current learning rate: 0.00014
# Epoch 120500: train loss 2.2301, val loss 2.2364
# The current learning rate: 0.00014
# Epoch 121000: train loss 2.2254, val loss 2.2351
# The current learning rate: 0.00014
# Epoch 121500: train loss 2.2247, val loss 2.2312
# The current learning rate: 0.00014
# Epoch 122000: train loss 2.2251, val loss 2.2245
# The current learning rate: 0.00014
# Epoch 122500: train loss 2.2196, val loss 2.2285
# The current learning rate: 0.00014
# Epoch 123000: train loss 2.2141, val loss 2.2242
# The current learning rate: 0.00014
# Epoch 123500: train loss 2.2139, val loss 2.2166
# The current learning rate: 0.00014
# Epoch 124000: train loss 2.2111, val loss 2.2139
# The current learning rate: 0.00014
# Epoch 124500: train loss 2.2135, val loss 2.2140
# The current learning rate: 0.00014
# Epoch 125000: train loss 2.2136, val loss 2.2169
# The current learning rate: 0.00014
# Epoch 125500: train loss 2.2150, val loss 2.2106
# The current learning rate: 0.00014
# Epoch 126000: train loss 2.2122, val loss 2.2093
# The current learning rate: 0.00014
# Epoch 126500: train loss 2.2114, val loss 2.2147
# The current learning rate: 0.00014
# Epoch 127000: train loss 2.2022, val loss 2.2022
# The current learning rate: 0.00014
# Epoch 127500: train loss 2.2008, val loss 2.2083
# The current learning rate: 0.00014
# Epoch 128000: train loss 2.2039, val loss 2.2085
# The current learning rate: 0.00014
# Epoch 128500: train loss 2.1995, val loss 2.2081
# The current learning rate: 0.00014
# Epoch 129000: train loss 2.1932, val loss 2.1962
# The current learning rate: 0.00014
# Epoch 129500: train loss 2.2007, val loss 2.1969
# The current learning rate: 0.00014
# Epoch 130000: train loss 2.2006, val loss 2.1965
# The current learning rate: 0.00014
# Epoch 130500: train loss 2.1922, val loss 2.1920
# The current learning rate: 0.00014
# Epoch 131000: train loss 2.1935, val loss 2.1902
# The current learning rate: 0.00014
# Epoch 131500: train loss 2.1834, val loss 2.1861
# The current learning rate: 0.00015
# Epoch 132000: train loss 2.1843, val loss 2.1895
# The current learning rate: 0.00015
# Epoch 132500: train loss 2.1841, val loss 2.1868
# The current learning rate: 0.00015
# Epoch 133000: train loss 2.1796, val loss 2.1863
# The current learning rate: 0.00015
# Epoch 133500: train loss 2.1796, val loss 2.1812
# The current learning rate: 0.00015
# Epoch 134000: train loss 2.1765, val loss 2.1777
# The current learning rate: 0.00015
# Epoch 134500: train loss 2.1747, val loss 2.1850
# The current learning rate: 0.00015
# Epoch 135000: train loss 2.1702, val loss 2.1768
# The current learning rate: 0.00015
# Epoch 135500: train loss 2.1719, val loss 2.1746
# The current learning rate: 0.00015
# Epoch 136000: train loss 2.1701, val loss 2.1787
# The current learning rate: 0.00015
# Epoch 136500: train loss 2.1738, val loss 2.1685
# The current learning rate: 0.00015
# Epoch 137000: train loss 2.1663, val loss 2.1736
# The current learning rate: 0.00015
# Epoch 137500: train loss 2.1643, val loss 2.1629
# The current learning rate: 0.00015
# Epoch 138000: train loss 2.1734, val loss 2.1680
# The current learning rate: 0.00015
# Epoch 138500: train loss 2.1699, val loss 2.1637
# The current learning rate: 0.00015
# Epoch 139000: train loss 2.1638, val loss 2.1650
# The current learning rate: 0.00015
# Epoch 139500: train loss 2.1617, val loss 2.1693
# The current learning rate: 0.00015
# Epoch 140000: train loss 2.1631, val loss 2.1689
# The current learning rate: 0.00015
# Epoch 140500: train loss 2.1506, val loss 2.1622
# The current learning rate: 0.00015
# Epoch 141000: train loss 2.1573, val loss 2.1566
# The current learning rate: 0.00015
# Epoch 141500: train loss 2.1523, val loss 2.1609
# The current learning rate: 0.00015
# Epoch 142000: train loss 2.1546, val loss 2.1528
# The current learning rate: 0.00015
# Epoch 142500: train loss 2.1517, val loss 2.1603
# The current learning rate: 0.00015
# Epoch 143000: train loss 2.1529, val loss 2.1546
# The current learning rate: 0.00015
# Epoch 143500: train loss 2.1400, val loss 2.1562
# The current learning rate: 0.00015
# Epoch 144000: train loss 2.1531, val loss 2.1528
# The current learning rate: 0.00015
# Epoch 144500: train loss 2.1451, val loss 2.1478
# The current learning rate: 0.00015
# Epoch 145000: train loss 2.1420, val loss 2.1420
# The current learning rate: 0.00015
# Epoch 145500: train loss 2.1408, val loss 2.1458
# The current learning rate: 0.00015
# Epoch 146000: train loss 2.1312, val loss 2.1422
# The current learning rate: 0.00016
# Epoch 146500: train loss 2.1359, val loss 2.1381
# The current learning rate: 0.00016
# Epoch 147000: train loss 2.1337, val loss 2.1350
# The current learning rate: 0.00016
# Epoch 147500: train loss 2.1324, val loss 2.1348
# The current learning rate: 0.00016
# Epoch 148000: train loss 2.1329, val loss 2.1379
# The current learning rate: 0.00016
# Epoch 148500: train loss 2.1300, val loss 2.1345
# The current learning rate: 0.00016
# Epoch 149000: train loss 2.1356, val loss 2.1324
# The current learning rate: 0.00016
# Epoch 149500: train loss 2.1268, val loss 2.1312
# The current learning rate: 0.00016
# Epoch 150000: train loss 2.1276, val loss 2.1324
# The current learning rate: 0.00016
# Epoch 150500: train loss 2.1262, val loss 2.1306
# The current learning rate: 0.00016
# Epoch 151000: train loss 2.1225, val loss 2.1268
# The current learning rate: 0.00016
# Epoch 151500: train loss 2.1229, val loss 2.1241
# The current learning rate: 0.00016
# Epoch 152000: train loss 2.1141, val loss 2.1272
# The current learning rate: 0.00016
# Epoch 152500: train loss 2.1148, val loss 2.1205
# The current learning rate: 0.00016
# Epoch 153000: train loss 2.1196, val loss 2.1233
# The current learning rate: 0.00016
# Epoch 153500: train loss 2.1175, val loss 2.1185
# The current learning rate: 0.00016
# Epoch 154000: train loss 2.1188, val loss 2.1180
# The current learning rate: 0.00016
# Epoch 154500: train loss 2.1155, val loss 2.1213
# The current learning rate: 0.00016
# Epoch 155000: train loss 2.1170, val loss 2.1204
# The current learning rate: 0.00016
# Epoch 155500: train loss 2.1160, val loss 2.1097
# The current learning rate: 0.00016
# Epoch 156000: train loss 2.1110, val loss 2.1142
# The current learning rate: 0.00016
# Epoch 156500: train loss 2.1013, val loss 2.1105
# The current learning rate: 0.00016
# Epoch 157000: train loss 2.1060, val loss 2.1109
# The current learning rate: 0.00016
# Epoch 157500: train loss 2.1029, val loss 2.1092
# The current learning rate: 0.00016
# Epoch 158000: train loss 2.1062, val loss 2.1083
# The current learning rate: 0.00016

# %%
import matplotlib.pyplot as plt
train_loss_list_converted = [i.cpu().detach() for i in train_loss_list]
validation_loss_list_converted = [i.cpu().detach() for i in validation_loss_list]
plt.plot(train_loss_list_converted, 'g', label = 'train_loss')
plt.plot(validation_loss_list_converted, 'r', label='validation_loss')
plt.xlabel("Steps - Every 100 epochs")
plt.ylabel("Loss")
plt.legend()
plt.xlim(0, 500)
plt.show()
np.savetxt('train_loss.csv', train_loss_list_converted, delimiter=',')

# %% [markdown]
# # Inference

# %%
#Load the model
nanoGPT = GPT.GPT(config)
device =  "cuda" if torch.cuda.is_available() else "cpu"
best_model_params_path = "best_model_params.pt"
nanoGPT.load_state_dict(torch.load(best_model_params_path, map_location=torch.device(device))) # load best model states
# Out:
# number of parameters: 15.00M
# <ipython-input-18-d4e888674873>:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   nanoGPT.load_state_dict(torch.load(best_model_params_path, map_location=torch.device(device))) # load best model states
# <All keys matched successfully>

# %%
sentence = "Once upon a time there was a pumpkin."
context = (torch.tensor(enc.encode_ordinary(sentence)).unsqueeze(dim = 0))
y = nanoGPT.generate(context, 200)
print(enc.decode(y.squeeze().tolist()))
# Out:
# Once upon a time there was a pumpkin. It was a different shape, and it was her name. It was beautiful. She wanted to make lots of cool things with it.
#
# So she got to work and worked together. She put the pumpkin up on the circle and cracked it and shone like a big bubble.
#
# Then, the little orange made a frog. She was so happy. She felt like a huge bird of a big berry.
#
# The little purple frog was no longer lonely. She thought it would be more fun to finish. She grabbed a big paper basket with all sorts of gem and markers. She stood in sign to all the berry and smiled, feeling so happy.
#
# On day, two of twinkling: One of them had a fight:bugs: the overlook: Tom's joke! But the putny bunns and a berry, it was a friendly crocod Clarey integrating. Tom's mom and she wanted to make the little bear, bigger and mottoet

# %%
from google.colab import runtime
runtime.unassign()
